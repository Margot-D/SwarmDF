# %% [markdown]
# # Swarm Data Fusion toolbox demo notebook

# %% [markdown]
# **SwarmDF is a Python tool for end-to-end automated data fusion, electrodynamics reconstruction, and validation along a Swarm satellite trajectory. It enables interpretation of Swarm observations within their broader electrodynamic context, supporting well-constrained studies of high-latitude ionospheric electrodynamics.**
#
# This notebook documents the SwarmDF Python module and guides the reader step by step through a typical workflow.
#
# Users may run `app.py` to access a user-friendly graphical user interface, which provides guidance through the workflow and allows user to run their own experiment.

# %% [markdown]
# ## Imports

# %%
from datetime import datetime
from IPython.display import Image as IPImage, display
from pathlib import Path

from swarmdf import *
from swarmdf.config import SwarmDFPlotSettings

# %% [markdown]
# Path to output directory

# %%
output_dir = Path.home() / "SwarmDF" / "outputs"
output_dir
# Out:
# PosixPath('/Users/margot/SwarmDF/outputs')

# %% [markdown]
# ## Input

# %% [markdown]
# ### Satellite and time
#
# **We start by selecting a Swarm satellite and defining the time interval and time step for our study.**
#
# The time interval defines the portion of the satellite trajectory used for the analysis. If it spans multiple Swarm passes, multiple trajectory segments are included.
#
# SwarmDF will perform the analysis at each time step along the selected trajectory.

# %%
sat_id = 'B'
start = datetime(2014, 12, 15, 1, 10, 0)
end   = datetime(2014, 12, 15, 1, 13, 0) #20
time_step = int(30) # [s] (minimum 10 s)

# %% [markdown]
# This is the only required input for running SwarmDF. All other parameters will use default values if not specified.

# %% [markdown]
# ### Grids along the Swarm trajectory
#
# **Next, we define the extent and spatial resolution of the 2D analysis grids.**
#
# SwarmDF will build cubed-sphere grids along the Swarm trajectory. These grids define the analysis region around the selected satellite at each time step. They are centered on the satellite track and aligned with its velocity vector.
#
# The start and end times above actually specify where the first and last analysis grids are centered along the trajectory. Additional grid centers are placed between them according to the chosen time step. In other words, the time interval specified above defines the range of grid centers, not the exact analysis bounds.
#
# The real analysis interval for each grid is determined dynamically during processing and depends on the grid size. Each grid uses all available data within its spatial extent.

# %%
# The grid parameters must be provided as a dictionary
grid_params = {"L": 2000, # along-track dimension [km] 
               "W": 1500, # cross-track dimension [km]
               "Lres": 80, # along-track resolution [km]
               "Wres": 80, # cross-track resolution [km]
               "wshift": 0} # cross-track shift of grid center [km]

# %% [markdown]
# Note on `wshift`:
# The Swarm trajectory is intended to pass through the center of each grid. However, depending on the grid dimensions and geometry, it may be slightly offset.
# `wshift` allows us to shift the grid center in the cross-track direction to better align it with the Swarm track. A positive (negative) value shifts the grid center to the left (right).

# %% [markdown]
# ### Datasets
#
# **Now, we choose datasets** from:
# - Swarm (magnetic field and cross-track ion drift)
# - SuperDARN (line-of-sight velocities)
# - SuperMAG (ground magnetometer perturbations)
# - Iridium/AMPERE (field-aligned currents)
# - DMSP/SSIES (ion drift)
#
# The selected datasets will be used to reconstruct the ionospheric electrodynamics across the sequence of grids along the Swarm trajectory.
#
# Data documentation is available at (link) ⚠️ TODO

# %%
# Supported dataset names: 
# 'superdarn', 'supermag', 'iridium_ampere', 'swarm_mag', 'swarm_efi', 'dmsp_ssies17', 'dmsp_ssies18' 

datasets2download = ['swarm_mag', 'swarm_efi', 'superdarn', 'supermag', 'iridium_ampere', "dmsp_ssies17", "dmsp_ssies18"]

# %% [markdown]
# **From this point on, everything is handled automatically by SwarmDF, up to the validation stage.**
#
# The Lompe reconstruction (see below) will use default conductance and regularization parameters unless specified otherwise.

# %% [markdown]
# ## Data fusion

# %% [markdown]
# **Data loading**
#
# SwarmDF automatically retrieves and loads all available datasets for the specified time interval.

# %%
datahandler = DataManager(start, end, datasets2download, use_sample_data = False) # Turn demo to True if you want to skip data collection and use sample datasets for example event 2014-12-15
datasets = datahandler.datasets # dictionnary of DataFrames
# Out:
# Downloading/retrieving data...
# Retrieving SuperMAG data for 2014-12-15: 100%|██████████| 118/118 [00:40<00:00,  2.91station/s]
# SuperMAG download complete: /Users/margot/SwarmDF/data/20141215_supermag.h5
# Retrieving DMSP/SSIES F18 for 2014-12-15: 100%|██████████| 100/100 [01:03<00:00,  1.57it/s]
# DMSP/SSIES F18 download complete: /Users/margot/SwarmDF/data/20141215_ssies_f18.h5
# Retrieving Swarm EFI data for 2014-12-15: 100%|██████████| 3/3 [00:02<00:00,  1.28it/s]
# No Swarm EFI data available for 2014-12-15. No file was created.
# Retrieving SuperDARN for 2014-12-15: 100%|██████████| 100/100 [01:22<00:00,  1.21it/s]
# SuperDARN download complete: /Users/margot/SwarmDF/data/20141215_superdarn_grdmap.h5
# Retrieving DMSP/SSIES F17 for 2014-12-15: 100%|██████████| 100/100 [01:04<00:00,  1.55it/s]
# DMSP/SSIES F17 download complete: /Users/margot/SwarmDF/data/20141215_ssies_f17.h5
# Retrieving Swarm MAG data for 2014-12-15: 100%|██████████| 3/3 [00:07<00:00,  2.62s/it]
# Swarm MAG download complete: /Users/margot/SwarmDF/data/20141215_swarm_mag.h5
# Retrieving Iridium/AMPERE data for 2014-12-15: 100%|██████████| 100/100 [01:49<00:00,  1.10s/it]
# Iridium/AMPERE download complete: /Users/margot/SwarmDF/data/20141215_iridium.h5
# Loading data...
# swarm_mag dataset successfully loaded
# No file found for swarm_efi
# superdarn dataset successfully loaded
# supermag dataset successfully loaded
# iridium_ampere dataset successfully loaded
# dmsp_ssies17 dataset successfully loaded
# dmsp_ssies18 dataset successfully loaded

# %% [markdown]
# **Lompe input preparation**
#
# Here, SwarmDF:
# - Extracts the relevant portion of the Swarm trajectory
# - Constructs analysis grids along the trajectory
# - Builds Lompe data objects for each grid (data ready for inversion)

# %%
input_builder = LompeInputBuilder(sat_id, start, end, time_step, datasets)
swarm_passes, grids, analysis_times = input_builder.build_grids_around_swarm(grid_params)
data_objects_per_grid = input_builder.prepare_lompe_input(grids, analysis_times)
# Out:
# test, what"s in datasets?
# {'swarm_mag':                          QDLat Spacecraft        MLT           F  \
# Timestamp
# 2014-12-15 00:00:00  31.439939          A  15.307295  33871.6043
# 2014-12-15 00:00:00  39.474663          B  16.613518  37106.1070
# 2014-12-15 00:00:00  31.201914          C  15.412182         NaN
# 2014-12-15 00:00:05  31.116922          A  15.312681  33726.0491
# 2014-12-15 00:00:05  39.154778          B  16.616661  36958.4993
# ...                        ...        ...        ...         ...
# 2014-12-15 23:59:50 -73.590637          A  22.041210  40858.0673
# 2014-12-15 23:59:50 -21.967407          B  17.283342  25114.2271
# 2014-12-15 23:59:55 -22.261166          B  17.289583  25196.5432
# 2014-12-15 23:59:56  102.937366  0.974615 -0.223886      4.0
# 2014-12-15 23:59:57  102.941465  0.974599 -0.223955      4.0
# 2014-12-15 23:59:58  102.945545  0.974583 -0.224025      4.0
# 2014-12-15 23:59:59         NaN       NaN       NaN      4.0
#
# [86400 rows x 9 columns]}
# Building analysis grids...
# Skipped 2 low-latitude grids (extending equatorward of |48|°)
# Preparing Lompe input...
# Done. Returning Lompe data objects.

# %% [markdown]
# **Next, we visualize the Lompe input to inspect the experiment configuration.**
#
# This step visualizes the input data used for the Lompe analysis along the selected Swarm trajectory. It allows us to inspect the geometry and data coverage.
#
# For each analysis grid, SwarmDF:
# - plots the Swarm tracks (A/B/C) for the current pass
# - overlays data from selected datasets inside the grid
# - optionally shows all available data within analysis time interval
# - saves each frame as a PNG and optionally compiles them into a GIF animation
#
# Each frame contains two panels:
# - a polar view (left) showing the analysis grid in its global context along the Swarm trajectory
# - a cubed-sphere view (right) showing the individual grid and the data within it.

# %%
plot_settings = SwarmDFPlotSettings(mag_coords_flag=True,
                                    show_all_data_flag=True,
                                    gif_speed=550, 
                                    generate_gifs=True)

# %%
input_plotter = LompeInputPlotter()
input_frames = input_plotter.plot_lompe_input(swarm_passes, grids, analysis_times, data_objects_per_grid, datasets, plot_settings)    

# Display GIF
gif_files = sorted(output_dir.glob("input_*.gif"), key=lambda f: f.stat().st_mtime)
latest_gif = gif_files[-1] # grab newest GIF in folder
display(IPImage(filename=latest_gif))
# Out:
# Plotting Lompe input...
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:585: RuntimeWarning: Mean of empty slice
#   return np.rad2deg(np.arctan2(np.nanmean(np.sin(np.deg2rad(X)),axis=axis),np.nanmean(np.cos(np.deg2rad(X)),axis=axis)))
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:229: RuntimeWarning: Mean of empty slice
#   lat_mean = np.nanmean(np.where(~iii,np.nan,lat[:,None]),axis=0) # mean of lat grid lines
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:585: RuntimeWarning: Mean of empty slice
#   return np.rad2deg(np.arctan2(np.nanmean(np.sin(np.deg2rad(X)),axis=axis),np.nanmean(np.cos(np.deg2rad(X)),axis=axis)))
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:229: RuntimeWarning: Mean of empty slice
#   lat_mean = np.nanmean(np.where(~iii,np.nan,lat[:,None]),axis=0) # mean of lat grid lines
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:585: RuntimeWarning: Mean of empty slice
#   return np.rad2deg(np.arctan2(np.nanmean(np.sin(np.deg2rad(X)),axis=axis),np.nanmean(np.cos(np.deg2rad(X)),axis=axis)))
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:229: RuntimeWarning: Mean of empty slice
#   lat_mean = np.nanmean(np.where(~iii,np.nan,lat[:,None]),axis=0) # mean of lat grid lines
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:585: RuntimeWarning: Mean of empty slice
#   return np.rad2deg(np.arctan2(np.nanmean(np.sin(np.deg2rad(X)),axis=axis),np.nanmean(np.cos(np.deg2rad(X)),axis=axis)))
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:229: RuntimeWarning: Mean of empty slice
#   lat_mean = np.nanmean(np.where(~iii,np.nan,lat[:,None]),axis=0) # mean of lat grid lines
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:585: RuntimeWarning: Mean of empty slice
#   return np.rad2deg(np.arctan2(np.nanmean(np.sin(np.deg2rad(X)),axis=axis),np.nanmean(np.cos(np.deg2rad(X)),axis=axis)))
# /Users/margot/Docs/Academia/Research/Python/secsy/src/secsy/csplot.py:229: RuntimeWarning: Mean of empty slice
#   lat_mean = np.nanmean(np.where(~iii,np.nan,lat[:,None]),axis=0) # mean of lat grid lines
# Figures with Swarm tracks, analysis grid, and data distribution for each time step saved in: /Users/margot/Docs/Academia/Research/Python/SwarmDF/outputs/tmp
# GIF saved in outputs directory as: /Users/margot/Docs/Academia/Research/Python/SwarmDF/outputs/input_swB_20141215_010845-20141215_011510.gif
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 6
#       4 # Display GIF
#       5 gif_files = sorted(output_dir.glob("input_*.gif"), key=lambda f: f.stat().st_mtime)
# ----> 6 latest_gif = gif_files[-1] # grab newest GIF in folder
#       7 display(IPImage(filename=latest_gif))
#
# IndexError: list index out of range

# %% [markdown]
# ## Lompe reconstruction

# %% [markdown]
# SwarmDF uses the [Lompe technique](https://agupubs.onlinelibrary.wiley.com/doi/10.1029/2022JA030356) to reconstruct the 2D ionospheric electrodynamics within each grid along the Swarm trajectory.
#
# Lompe formulates the reconstruction as a linear inverse problem, combining various observations (including magnetic field perturbations on ground and in space, plasma convection, electric fields, and field-aligned currents) into a common model based on Spherical Elementary Current Systems (SECS). Solving for these parameters yields consistent estimates of electric fields, currents, and magnetic perturbations across the analysis region.
#
# The method is flexible in both spatial extent and resolution, allowing it to adapt to the geometry and coverage of the available data. This makes it well suited for SwarmDF, where the analysis region is defined dynamically along a satellite trajectory and data coverage is heterogeneous.

# %% [markdown]
# **Ionospheric conductance estimates**
#
# Conductances are a key input to the Lompe inversion and are treated as known quantities in order to keep the problem linear.
#
# While this simplifies the inversion, ionospheric conductances are not directly known with high accuracy. They are strongly affected by auroral precipitation, which can vary rapidly in space and time. In contrast, the contribution from solar EUV radiation is more stable and better constrained.
#
# Lompe includes a built-in model for solar EUV-driven conductance, as well as implementations of the Hardy and Zhang & Paxton models for auroral precipitation.
#
# Conductance estimates are computed using the following inputs:
#
# - Kp index (used in the Hardy model)
# - solar radio flux at 10.7 cm, used to scale EUV conductance
# - a background conductance term

# %%
# Supported models: 'Zhang & Paxton model', 'Hardy model'
conductance_method = 'Zhang & Paxton model'

kp_value = 4 # Kp index (geomagnetic activity indicator)
f107_value = 100 # [s.f.u] Solar radio flux at 10.7 cm (solar activity indicator)
background_value = 2 # Background conductance (constant offset term)

# Dictionnary of input parameters
conductance_params = {"kp": kp_value, "f107": f107_value, "background": background_value}

# Compute Hall and Pedersen conductances
SHs, SPs = compute_conductances(conductance_method, conductance_params, analysis_times, grids)

# %% [markdown]
# **Regularization parameters** (⚠️ OK?)
#
# Lompe uses two regularization parameters to control different aspects of the solution.
#
# The first parameter (l1) penalizes rapid spatial variations in the model solution, and therefore controls the overall smoothness of the reconstructed fields. Increasing this parameter produces smoother solutions, while decreasing it allows more small-scale structure and closer fitting to the observations.
#
# The second parameter (l2) controls the strength of the SECS-based regularization, which constrains the structure and amplitude of the ionospheric current system representation. Increasing this parameter enforces a more constrained current system, while decreasing it allows more flexibility in the reconstructed currents.
#
# More generally, regularization represents prior assumptions about the expected structure of the ionospheric electrodynamics. The parameters determine how strongly these assumptions are enforced relative to the fit to the observations. Finding appropriate values typically requires some experimentation.

# %%
l1 = 1 # smoothness of solution
l2 = 1 # SECS regularization strength in magnetic eastward direction

# %% [markdown]
# **Lompe inversion along the Swarm trajectory**
#
# SwarmDF applies the Lompe technique across the sequence of grids along the Swarm trajectory.

# %%
# run_lompe returns a dictionnary of Lompe models (one model per grid)
lompe_model_objects = run_lompe(grids, analysis_times, data_objects_per_grid, SHs, SPs, l1, l2)
# Out:
# Running Lompe analysis (l1=1.00, l2=1.00)...
# Frame 1/5
# Frame 2/5
# Frame 3/5
# Frame 4/5
# Frame 5/5
# Done. Returning Lompe inversion results.

# %% [markdown]
# **Finally, we visualize the reconstructed electrodynamic quantities along the Swarm trajectory.**
#
# Lompe combined different types of measurements to provide a consistent picture of ionospheric electrodynamics within each grid along the selected trajectory.
#
# In the figure below, input data are shown as orange vectors, while the Lompe solution is represented by contours (red/blue) and black vectors.
#
# The reconstructed quantities include:
# - convection flow field (vectors) and electric potential (contours) *(top left panel)*
# - radial current density (contours) and horizontal magnetic field disturbances in space (vectors) *(top middle panel)*
# - horizontal magnetic field perturbations on ground (vectors) and radial magnetic field perturbations (contours) *(top right panel)*
# - Hall and Pedersen conductances *(bottom left and middle panels)*
# - horizontal height-integrated ionospheric currents *(bottom right panel)*
#
# The panel on the right shows the grid position and orientation in apex magnetic latitude and local time. All other panels are shown in geographic coordinates.
#
# The upper color scale corresponds to conductances (mho), while the lower one corresponds to radial magnetic field perturbations (nT) and radial current density (µA/m²).
#
# <!-- The uncertainty in the Lompe estimates depends on the distribution of the data, measurement error, and on how the data are related to electric field amplitudes via the ionospheric Ohm's law. -->

# %%
output_frames = plot_lompe_output(lompe_model_objects, sat_id, plot_settings) 

# Display GIF
gif_files = sorted(output_dir.glob("lompe_*.gif"), key=lambda f: f.stat().st_mtime) 
latest_gif = gif_files[-1] # grab newest GIF in folder
display(IPImage(filename=latest_gif))
# Out:
# Plotting Lompe output...
# Lompe output figures for each time step saved in temporary folder: /Users/margot/Docs/Academia/Research/Python/SwarmDF/outputs/tmp
# GIF saved in outputs directory: /Users/margot/Docs/Academia/Research/Python/SwarmDF/outputs/lompe_swB_20141215_010845-20141215_011510.gif

# %% [markdown]
# ## Validation
#
# In real observations, the true ionospheric electrodynamics are unknown, which makes it difficult to directly evaluate the accuracy of a Lompe reconstruction. The result depends on factors such as data coverage and grid configuration, but there is no reference “truth” for comparison.
#
# SwarmDF overcomes this limitation by including a validation tool, [LompeOSSE](https://github.com/Margot-D/lompe_osse), based on Observation System Simulation Experiments (OSSEs). LompeOSSE uses synthetic electrodynamics from Gamera simulations to evaluate the experiment configuration and the performance of the Lompe inversion.
#
# ⚠️ Note: LompeOSSE is still under development and is not yet publicly available. This part of the notebook is therefore not functional at the moment.

# %% [markdown]
# **Input to LompeOSSE**
#
# The main input to LompeOSSE is the set of Lompe models generated during the previous inversion step.
#
# Two optional parameters allow exploration of different physical configurations in the Gamera simulation:
# - snapshot: selects a specific Gamera simulation run, each representing a different physical scenario
# - time_offset: rotates the Gamera snapshot in magnetic local time (MLT)
#
# For further details, see the LompeOSSE documentation.

# %%
# Available Gamera snapshots: 
#0 #2 #3 #12 #13 #14 #16 #19 #20 #21 #22 
# (inspect with find-Gamera-snapshot.py in LompeOSSE)

snapshot = 0
time_offset = 0 # [MLT hours]

# %% [markdown]
# **LompeOSSE analysis along the Swarm trajectory**
#
# SwarmDF applies LompeOSSE in each grid along the Swarm trajectory.
#
# In each analysis region, observational inputs to the Lompe model are replaced with synthetic data derived from Gamera simulations, while the grid configuration and data coverage are kept unchanged. The Lompe inversion is then applied to the synthetic datasets, and the reconstructed electrodynamics can be directly compared to the known reference state from the simulation.
#
# This makes it possible to evaluate how factors such as data availability and grid resolution affect the reconstruction.
#
# `run_lompeOSSE` returns the synthetic Lompe models, and the set of synthetic electrodynamic quantities across grids along the selected Swarm trajectory.

# %%
lompeOSSE_model_objects, gamera_quantities = run_lompeOSSE(lompe_model_objects, time_offset, snapshot)
# Out:
# Running LompeOSSE validation...
# Frame 1/5
#
# Loading Gamera data/snapshot #0
# Gamera_output 0.049971291911788285
# LompeOSSE 2.8333044610917568e-05
#
#  Initializing synthetic model (2014-12-15 01:11:00)...
#
#  Scanning user datasets and searching for corresponding Gamera data...
# efield dataset not found
# convection dataset not found
# ground_mag dataset found..
# Getting Gamera magnetic field data
# ..Gamera ground_mag data extracted
# get_B: 3.956889291992411
# space_mag_full dataset not found
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 3.674524207948707
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 3.719573416048661
# fac dataset not found
# extract qunatities: 11.351467667031102
# extract conductances: 8.582952432334423e-06
#
#  Clearing input model...
# Adding Gamera datasets
# ...Synthetic model generated
# total make_osse_model 11.351518291980028
# make_osse_model 11.35153458302375
# Frame 2/5
#
# Loading Gamera data/snapshot #0
# Gamera_output 0.02305091603193432
# LompeOSSE 2.358399797230959e-05
#
#  Initializing synthetic model (2014-12-15 01:11:30)...
#
#  Scanning user datasets and searching for corresponding Gamera data...
# efield dataset not found
# convection dataset not found
# ground_mag dataset found..
# Getting Gamera magnetic field data
# ..Gamera ground_mag data extracted
# get_B: 3.5179006250109524
# space_mag_full dataset not found
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 4.021548749995418
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 3.6681778338970616
# fac dataset not found
# extract qunatities: 11.208101874915883
# extract conductances: 2.084067091345787e-06
#
#  Clearing input model...
# Adding Gamera datasets
# ...Synthetic model generated
# total make_osse_model 11.20814220898319
# make_osse_model 11.20822962501552
# Frame 3/5
#
# Loading Gamera data/snapshot #0
# Gamera_output 0.024741207947954535
# LompeOSSE 2.4417066015303135e-05
#
#  Initializing synthetic model (2014-12-15 01:12:00)...
#
#  Scanning user datasets and searching for corresponding Gamera data...
# efield dataset not found
# convection dataset not found
# ground_mag dataset found..
# Getting Gamera magnetic field data
# ..Gamera ground_mag data extracted
# get_B: 3.7023603749694303
# space_mag_full dataset not found
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 4.069143374916166
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 3.4578772500390187
# fac dataset not found
# extract qunatities: 11.229992334032431
# extract conductances: 1.5409896150231361e-06
#
#  Clearing input model...
# Adding Gamera datasets
# ...Synthetic model generated
# total make_osse_model 11.230036334018223
# make_osse_model 11.230100249988027
# Frame 4/5
#
# Loading Gamera data/snapshot #0
# Gamera_output 0.023629416013136506
# LompeOSSE 2.158398274332285e-05
#
#  Initializing synthetic model (2014-12-15 01:12:30)...
#
#  Scanning user datasets and searching for corresponding Gamera data...
# efield dataset not found
# convection dataset not found
# ground_mag dataset found..
# Getting Gamera magnetic field data
# ..Gamera ground_mag data extracted
# get_B: 3.50601699994877
# space_mag_full dataset not found
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 4.022346916026436
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 3.6480381669243798
# fac dataset not found
# extract qunatities: 11.17697045893874
# extract conductances: 4.208064638078213e-06
#
#  Clearing input model...
# Adding Gamera datasets
# ...Synthetic model generated
# total make_osse_model 11.177038166904822
# make_osse_model 11.177090666024014
# Frame 5/5
#
# Loading Gamera data/snapshot #0
# Gamera_output 0.024241666891612113
# LompeOSSE 2.550007775425911e-05
#
#  Initializing synthetic model (2014-12-15 01:13:00)...
#
#  Scanning user datasets and searching for corresponding Gamera data...
# efield dataset not found
# convection dataset not found
# ground_mag dataset found..
# Getting Gamera magnetic field data
# ..Gamera ground_mag data extracted
# get_B: 3.55348124995362
# space_mag_full dataset not found
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 4.548476124997251
# space_mag_fac dataset found..
# Getting Gamera magnetic field data
# ..Gamera space_mag_fac data extracted
# get_B: 3.8727957499213517
# fac dataset not found
# extract qunatities: 11.975339791970327
# extract conductances: 1.1499971151351929e-05
#
#  Clearing input model...
# Adding Gamera datasets
# ...Synthetic model generated
# total make_osse_model 11.975447957986034
# make_osse_model 11.975586541928351
# Done. Returning LompeOSSE inversion results and Gamera outputs.

# %% [markdown]
# **We can finally assess the reconstruction accuracy.**
#
# The synthetic electrodynamics from Gamera simulations provide a known reference state, allowing direct comparison between:
# - the original (“truth”) fields, and
# - the fields reconstructed by LompeOSSE.
#
# Agreement between the two indicates good reconstruction performance.
#
# <!-- ⚠️ Keep in mind that the gamera snapshot has an influence too?  -->

# %%
lompeOSSE_frames, gamera_frames = plot_lompeOSSE_output(lompeOSSE_model_objects, gamera_quantities, plot_settings)

# Display original Gamera GIF
Gamera_gifpath = output_dir / f"GAMERA_electrodynamics.gif"
display(IPImage(filename=Gamera_gifpath))

# Display OSSE-reconstruction GIF
lompeOSSE_gifpath = output_dir / f"lompeOSSE_electrodynamics.gif"
display(IPImage(filename=lompeOSSE_gifpath))
# Out:
#  Generating LompeOSSE output...
# ## 2014-12-15 01:11:00 ##
# Getting Gameraaa Hall conductance
# griddata: 12.139596958993934
# get Hall conductance FUNCTION: 14.779240540927276
# Getting Gameraaa Pedersen conductance
# griddata: 12.104544374975376
# get Pedersen conductance FUNCTION: 14.661159125040285
# Getting Gameraaa Hall conductance
# griddata: 11.867270542075858
# get Hall conductance FUNCTION: 14.569538084091619
# Getting Gameraaa Pedersen conductance
# griddata: 11.754313291981816
# get Pedersen conductance FUNCTION: 14.412947167060338
# Getting Gameraaa Hall conductance
# griddata: 11.29619299992919
# get Hall conductance FUNCTION: 13.945787541917525
# Getting Gameraaa Pedersen conductance
# griddata: 11.347090917057358
# get Pedersen conductance FUNCTION: 14.049179416964762
# Getting Gameraaa Hall conductance
# griddata: 11.378978125052527
# get Hall conductance FUNCTION: 13.972019999986514
# Getting Gameraaa Pedersen conductance
# griddata: 11.885756790987216
# get Pedersen conductance FUNCTION: 14.504835540894419
# Getting Gameraaa Hall conductance
# griddata: 11.385783125064336
# get Hall conductance FUNCTION: 13.958488459000364
# Getting Gameraaa Pedersen conductance
# griddata: 12.099709125002846
# get Pedersen conductance FUNCTION: 14.744912791997194
# Getting Gameraaa Hall conductance
# griddata: 11.744571499992162
# get Hall conductance FUNCTION: 14.316457374952734
# Getting Gameraaa Pedersen conductance
# griddata: 10.922624250059016
# get Pedersen conductance FUNCTION: 13.353441042010672
# lompeosseplot: 173.24113875010516
# Getting Gameraaa Potential
# griddata: 10.369329583947547
# Getting Gamera convection data
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.466168332961388
# in getE centered cs proj: 0.6967937920708209
# griddata xi: 10.982632708037272
# griddata eta: 10.780934583977796
# vector cube to geo: 0.0008077080128714442
# in getE interp to meas: 21.76478450000286
# Getting Gameraaa Field-aligned current
# griddata: 11.080308666918427
# Getting Gamera magnetic field data
# Getting Gamera magnetic field data
# Getting Gameraaa Pedersen conductance
# griddata: 10.70456737501081
# Getting Gameraaa Hall conductance
# griddata: 10.991227416903712
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.412093000020832
# in getE centered cs proj: 0.7076682080514729
# griddata xi: 11.033043749979697
# griddata eta: 7.974540583090857
# vector cube to geo: 0.0009907919447869062
# in getE interp to meas: 19.009113500011154
#
#  Generating LompeOSSE output...
# ## 2014-12-15 01:11:30 ##
# Getting Gameraaa Hall conductance
# griddata: 7.262756666983478
# get Hall conductance FUNCTION: 9.506146042025648
# Getting Gameraaa Pedersen conductance
# griddata: 7.200750750023872
# get Pedersen conductance FUNCTION: 9.453227167017758
# Getting Gameraaa Hall conductance
# griddata: 7.268871791078709
# get Hall conductance FUNCTION: 9.519780166912824
# Getting Gameraaa Pedersen conductance
# griddata: 6.043122707982548
# get Pedersen conductance FUNCTION: 8.271460417076014
# Getting Gameraaa Hall conductance
# griddata: 4.527736124931835
# get Hall conductance FUNCTION: 6.76173549995292
# Getting Gameraaa Pedersen conductance
# griddata: 6.216516624903306
# get Pedersen conductance FUNCTION: 8.444504250073805
# Getting Gameraaa Hall conductance
# griddata: 6.942362415953539
# get Hall conductance FUNCTION: 9.169278874993324
# Getting Gameraaa Pedersen conductance
# griddata: 6.598699958063662
# get Pedersen conductance FUNCTION: 8.829956833971664
# Getting Gameraaa Hall conductance
# griddata: 5.472197624971159
# get Hall conductance FUNCTION: 7.734129958902486
# Getting Gameraaa Pedersen conductance
# griddata: 5.6685316250659525
# get Pedersen conductance FUNCTION: 7.914257791009732
# Getting Gameraaa Hall conductance
# griddata: 6.931662291986868
# get Hall conductance FUNCTION: 9.189598207944073
# Getting Gameraaa Pedersen conductance
# griddata: 6.959813875029795
# get Pedersen conductance FUNCTION: 9.193556208978407
# lompeosseplot: 105.57630583399441
# Getting Gameraaa Potential
# griddata: 6.995584124932066
# Getting Gamera convection data
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.2440396660240367
# in getE centered cs proj: 0.7681482089683414
# griddata xi: 6.851593624916859
# griddata eta: 4.866179917007685
# vector cube to geo: 0.0009015830000862479
# in getE interp to meas: 11.718813957995735
# Getting Gameraaa Field-aligned current
# griddata: 7.009543625055812
# Getting Gamera magnetic field data
# Getting Gamera magnetic field data
# Getting Gameraaa Pedersen conductance
# griddata: 6.994252249947749
# Getting Gameraaa Hall conductance
# griddata: 7.03574233292602
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.2245372500037774
# in getE centered cs proj: 0.7201784170465544
# griddata xi: 7.05381304200273
# griddata eta: 6.622791915899143
# vector cube to geo: 0.0010493340669199824
# in getE interp to meas: 13.677872041938826
#
#  Generating LompeOSSE output...
# ## 2014-12-15 01:12:00 ##
# Getting Gameraaa Hall conductance
# griddata: 6.990062457975
# get Hall conductance FUNCTION: 9.202866832958534
# Getting Gameraaa Pedersen conductance
# griddata: 6.90862779202871
# get Pedersen conductance FUNCTION: 9.092005166923627
# Getting Gameraaa Hall conductance
# griddata: 6.862593457917683
# get Hall conductance FUNCTION: 9.04315616702661
# Getting Gameraaa Pedersen conductance
# griddata: 6.945620791986585
# get Pedersen conductance FUNCTION: 9.125244709081016
# Getting Gameraaa Hall conductance
# griddata: 6.947719458024949
# get Hall conductance FUNCTION: 9.150614749989472
# Getting Gameraaa Pedersen conductance
# griddata: 6.3404936250299215
# get Pedersen conductance FUNCTION: 8.535727083100937
# Getting Gameraaa Hall conductance
# griddata: 6.686521583003923
# get Hall conductance FUNCTION: 8.887283790973015
# Getting Gameraaa Pedersen conductance
# griddata: 7.2669127919944
# get Pedersen conductance FUNCTION: 9.45776829100214
# Getting Gameraaa Hall conductance
# griddata: 7.020315833971836
# get Hall conductance FUNCTION: 9.29058500006795
# Getting Gameraaa Pedersen conductance
# griddata: 7.041698791901581
# get Pedersen conductance FUNCTION: 9.33849170897156
# Getting Gameraaa Hall conductance
# griddata: 7.0916753329802305
# get Hall conductance FUNCTION: 9.404862708062865
# Getting Gameraaa Pedersen conductance
# griddata: 6.753284207894467
# get Pedersen conductance FUNCTION: 9.031841207994148
# lompeosseplot: 111.20623204205185
# Getting Gameraaa Potential
# griddata: 7.133530750055797
# Getting Gamera convection data
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.2888411660678685
# in getE centered cs proj: 0.8268083339789882
# griddata xi: 7.236966916010715
# griddata eta: 7.254840167006478
# vector cube to geo: 0.0008234999841079116
# in getE interp to meas: 14.492894374998286
# Getting Gameraaa Field-aligned current
# griddata: 7.059434458031319
# Getting Gamera magnetic field data
# Getting Gamera magnetic field data
# Getting Gameraaa Pedersen conductance
# griddata: 7.092258999939077
# Getting Gameraaa Hall conductance
# griddata: 7.136030749999918
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.328655792050995
# in getE centered cs proj: 0.7640212499536574
# griddata xi: 7.057782624964602
# griddata eta: 7.193989042076282
# vector cube to geo: 0.0007874580333009362
# in getE interp to meas: 14.252676583011635
#
#  Generating LompeOSSE output...
# ## 2014-12-15 01:12:30 ##
# Getting Gameraaa Hall conductance
# griddata: 7.187075958005153
# get Hall conductance FUNCTION: 9.44635958399158
# Getting Gameraaa Pedersen conductance
# griddata: 7.31793054100126
# get Pedersen conductance FUNCTION: 9.591550375102088
# Getting Gameraaa Hall conductance
# griddata: 7.219764333916828
# get Hall conductance FUNCTION: 9.481520792003721
# Getting Gameraaa Pedersen conductance
# griddata: 7.242856041993946
# get Pedersen conductance FUNCTION: 9.491237999987788
# Getting Gameraaa Hall conductance
# griddata: 7.25091408402659
# get Hall conductance FUNCTION: 9.463090708944947
# Getting Gameraaa Pedersen conductance
# griddata: 7.326926417066716
# get Pedersen conductance FUNCTION: 9.578841333044693
# Getting Gameraaa Hall conductance
# griddata: 7.222195666981861
# get Hall conductance FUNCTION: 9.473264041007496
# Getting Gameraaa Pedersen conductance
# griddata: 7.28246862499509
# get Pedersen conductance FUNCTION: 9.508455625036731
# Getting Gameraaa Hall conductance
# griddata: 7.160021582967602
# get Hall conductance FUNCTION: 9.398162667057477
# Getting Gameraaa Pedersen conductance
# griddata: 7.179015540983528
# get Pedersen conductance FUNCTION: 9.442444458021782
# Getting Gameraaa Hall conductance
# griddata: 7.271030124975368
# get Hall conductance FUNCTION: 9.63408779189922
# Getting Gameraaa Pedersen conductance
# griddata: 6.8594017080031335
# get Pedersen conductance FUNCTION: 9.10994762496557
# lompeosseplot: 115.2043629999971
# Getting Gameraaa Potential
# griddata: 7.0344945830293
# Getting Gamera convection data
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.2924987910082564
# in getE centered cs proj: 0.7463905839249492
# griddata xi: 7.239617499988526
# griddata eta: 7.171933667035773
# vector cube to geo: 0.0008325000526383519
# in getE interp to meas: 14.412494832999073
# Getting Gameraaa Field-aligned current
# griddata: 7.078411417081952
# Getting Gamera magnetic field data
# Getting Gamera magnetic field data
# Getting Gameraaa Pedersen conductance
# griddata: 7.11298358393833
# Getting Gameraaa Hall conductance
# griddata: 7.146732125082053
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.2911832500249147
# in getE centered cs proj: 0.7844839579192922
# griddata xi: 7.769797250046395
# griddata eta: 7.082547958008945
# vector cube to geo: 0.001083708950318396
# in getE interp to meas: 14.853580792085268
#
#  Generating LompeOSSE output...
# ## 2014-12-15 01:13:00 ##
# Getting Gameraaa Hall conductance
# griddata: 7.1220374590484425
# get Hall conductance FUNCTION: 9.385202124947682
# Getting Gameraaa Pedersen conductance
# griddata: 7.110859708045609
# get Pedersen conductance FUNCTION: 9.400583167094737
# Getting Gameraaa Hall conductance
# griddata: 7.117373583023436
# get Hall conductance FUNCTION: 9.41067691706121
# Getting Gameraaa Pedersen conductance
# griddata: 6.978213416994549
# get Pedersen conductance FUNCTION: 9.252471167012118
# Getting Gameraaa Hall conductance
# griddata: 7.120623041992076
# get Hall conductance FUNCTION: 9.453410833026282
# Getting Gameraaa Pedersen conductance
# griddata: 7.091195916989818
# get Pedersen conductance FUNCTION: 9.511559000005946
# Getting Gameraaa Hall conductance
# griddata: 6.867502624983899
# get Hall conductance FUNCTION: 9.138205208000727
# Getting Gameraaa Pedersen conductance
# griddata: 7.202408084063791
# get Pedersen conductance FUNCTION: 9.452602457953617
# Getting Gameraaa Hall conductance
# griddata: 7.172025875071995
# get Hall conductance FUNCTION: 9.406874125008471
# Getting Gameraaa Pedersen conductance
# griddata: 7.231219334062189
# get Pedersen conductance FUNCTION: 9.457674083998427
# Getting Gameraaa Hall conductance
# griddata: 7.392932457965799
# get Hall conductance FUNCTION: 9.632839165977202
# Getting Gameraaa Pedersen conductance
# griddata: 7.3056195001117885
# get Pedersen conductance FUNCTION: 9.530082041979767
# lompeosseplot: 114.60245341691189
# Getting Gameraaa Potential
# griddata: 7.324852125020698
# Getting Gamera convection data
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.2569133340148255
# in getE centered cs proj: 0.7387140829814598
# griddata xi: 7.277274708962068
# griddata eta: 7.162225208012387
# vector cube to geo: 0.0007600000826641917
# in getE interp to meas: 14.440383667009883
# Getting Gameraaa Field-aligned current
# griddata: 7.1411119169788435
# Getting Gamera magnetic field data
# Getting Gamera magnetic field data
# Getting Gameraaa Pedersen conductance
# griddata: 7.186769042047672
# Getting Gameraaa Hall conductance
# griddata: 7.150993374991231
# Getting Gamera electric field
# in getE gamera dipole to geo: 2.293282874976285
# in getE centered cs proj: 0.7864438329124823
# griddata xi: 7.199174166074954
# griddata eta: 7.126004833960906
# vector cube to geo: 0.0008139159763231874
# in getE interp to meas: 14.326089709065855
# LompeOSSE output figures for each time step saved in temporary folder: /Users/margot/Docs/Academia/Research/Python/SwarmDF/outputs/tmp
# GIF saved in outputs directory: /Users/margot/Docs/Academia/Research/Python/SwarmDF/outputs/lompeOSSE_20141215_010845-20141215_011510.gif and /Users/margot/Docs/Academia/Research/Python/SwarmDF/outputs/Gamera_20141215_010845-20141215_011510.gif

# %% [markdown]
# If visual inspection is not sufficient, we can quantify the agreement between the original synthetic fields and the Lompe reconstruction using correlation analysis.
#
# As an example, we compare the synthetic electric potential with its reconstructed counterpart.

# %%
import numpy as np 
import matplotlib.pyplot as plt
import io
import imageio.v2 as imageio
from PIL import Image as PILImage 

# # Re-run LompeOSSE with different parameters:
# snapshot=0
# time_offset=0
# lompeOSSE_model_objects, gamera_quantities = run_lompeOSSE(lompe_model_objects, time_offset, snapshot)

gameras = [entry["gamera_output"] for entry in gamera_quantities]
lompes = [entry["osse_model"] for entry in lompeOSSE_model_objects]
cts = [entry["ct"] for entry in lompeOSSE_model_objects]

figs=[]
for gamera, lompe, t in zip(gameras, lompes, cts):

    grid = lompe.grid_J

    # Extract electric potential from Gamera simulation
    truth_potential = gamera.get_potential(grid.lon, grid.lat, t) # in [V]

    # Extract electric potential from LompeOSSE reconstruction 
    recon_potential = lompe.E_pot(grid.lon, grid.lat, t) * 1e-3 # in [V]

    # Flatten data
    truth = np.asarray(truth_potential).ravel()
    recon = np.asarray(recon_potential).ravel()

    # Compute correlation
    corr = np.corrcoef(truth, recon)[0, 1]

    # Plot
    fig, ax = plt.subplots()

    ax.scatter(truth, recon, s=5, alpha=0.5)    
    ax.plot([truth.min(), truth.max()], [truth.min(), truth.max()], 'k--', linewidth=1)

    ax.set_xlabel("Synthetic (truth) potential")
    ax.set_ylabel("OSSE-reconstructed potential")
    ax.set_title(f"LompeOSSE validation: correlation = {corr:.3f} \n {t}")

    # Save figure to memory buffer
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    plt.close(fig)
    buf.seek(0)

    figs.append(imageio.imread(buf))

# Save GIF
images = [PILImage.fromarray(f) for f in figs]
images[0].save("correlation_plot.gif", save_all=True, append_images=images[1:], duration=750, loop=0)

# Display
display(IPImage(filename="correlation_plot.gif"))
# Out:
# Getting Gameraaa Potential
# griddata: 6.734036584035493
# Getting Gameraaa Potential
# griddata: 6.689248541952111
# Getting Gameraaa Potential
# griddata: 6.948208166984841
# Getting Gameraaa Potential
# griddata: 6.8946341660339385
# Getting Gameraaa Potential
# griddata: 6.947040166007355

# %% [markdown]
# The scatter plot compares synthetic truth and reconstructed electric potential.
# The dashed line indicates perfect agreement.
